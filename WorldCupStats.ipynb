# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
os.chdir('Desktop')

# %%
os.getcwd()
# Out:
# '/Users/tomjones/Desktop'

# %%
df = pd.read_csv('WorldCupStats.csv', encoding='latin-1')

# %%
df.head()
# Out:
#    Number              Name  Nat Pos  Height  Height_cm  Weight Date of Birth  \
# 0       1   EssamÊEl-Hadary  EGY   G    1.83        183      85    15/01/1973
# 1       2          Ali Gabr  EGY   D    1.93        193      74    10/01/1987
# 2       3  Ahmed Elmohamady  EGY   M    1.82        182      81    09/09/1987
# 3       4        Omar Gaber  EGY   D    1.74        174      71    30/01/1992
# 4       5         Sam Morsy  EGY   M    1.75        175      76    10/09/1991
#
#    Age          Birth Place              Current Club Group
# 0   45             Damietta                Al-Taawoun     A
# 1   31             Ismalia             WBA (On Loan)     A
# 2   30  El-Mahalla El-Kubra               Aston Villa     A
# 3   26                Cairo  Los Angeles FC (On Loan)     A
# 4   26        Wolverhampton                 Wigan Ath     A

# %%
df[df['Nat'] == 'GER']
# Out:
#      Number                   Name  Nat Pos  Height  Height_cm  Weight  \
# 460       1           Manuel Neuer  GER   G    1.92        192      90
# 461       2    Marvin Plattenhardt  GER   D    1.79        179      73
# 462       3           Jonas Hector  GER   D    1.85        185      73
# 463       4        Matthias Ginter  GER   D    1.87        187      82
# 464       5           Mats Hummels  GER   D    1.92        192      90
# 465       6           Sami Khedira  GER   M    1.89        189      90
# 466       7         Julian Draxler  GER   M    1.83        183      68
# 467       8             Toni Kroos  GER   M    1.83        183      76
# 468       9            Timo Werner  GER   F    1.80        180      75
# 469      10             Mesut
# zil  GER   M    1.80        180      76
# 470      11             Marco Reus  GER   F    1.80        180      75
# 471      12            Kevin Trapp  GER   G    1.89        189      83
# ...

# %%
group_position = df[['Pos','Height_cm']].sort_values(by=['Pos', 'Height_cm'], ascending = False)

# %%
group_position
# Out:
#     Pos  Height_cm
# 244   M        196
# 434   M        194
# 559   M        194
# 43    M        193
# 57    M        192
# 363   M        192
# 235   M        191
# 429   M        191
# 433   M        191
# 453   M        191
# 595   M        191
# 29    M        190
# 97    M        190
# 120   M        190
# 723   M        190
# 165   M        189
# 198   M        189
# 206   M        189
# 465   M        189
# 473   M        189
# 720   M        189
# 574   M        188
# 578   M        188
# 594   M        188
# 74    M        187
# 83    M        187
# 151   M        187
# 348   M        187
# 573   M        187
# 635   M        187
# ..   ..        ...
# 406   D        175
# 596   D        175
# 687   D        175
# 3     D        174
# 379   D        174
# 577   D        174
# 632   D        174
# 724   D        174
# 47    D        173
# 51    D        173
# 84    D        173
# 162   D        173
# 158   D        172
# 199   D        172
# 255   D        172
# ...

# %%
group_position.boxplot(by='Pos')

# %%
group_position.plot.scatter(x='Pos', y='Height_cm')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-60f7d4d641ed> in <module>()
# ----> 1 group_position.plot.scatter(x='Pos', y='Height_cm')
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/plotting/_core.py in scatter(self, x, y, s, c, **kwds)
#    3459             ...                       colormap='viridis')
#    3460         """
# -> 3461         return self(kind='scatter', x=x, y=y, c=c, s=s, **kwds)
#    3462
#    3463     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None,
#
# ...

# %%
import seaborn as sns

# %%
ax = sns.boxplot(x='Pos', y='Height_cm', data=df)

# %%
ax = sns.stripplot(x='Pos', y='Height_cm', data=df, color="grey", jitter = True)

# %%
ax1 = sns.swarmplot(x='Pos', y='Height_cm', data=df, color="grey")

# %%
ax2 = sns.stripplot(x='Pos', y='Height_cm', data=df, color="grey")

# %%
df2018winners = df[['Nat', 'Pos', 'Height_cm', 'Age']]

# %%
df2018winners = df2018winners[df2018winners['Nat'] == 'FRA']

# %%
df2018winners
# Out:
#      Nat Pos  Height_cm  Age
# 230  FRA   G        188   31
# 231  FRA   D        182   22
# 232  FRA   D        183   22
# 233  FRA   D        191   25
# 234  FRA   D        182   24
# 235  FRA   M        191   25
# 236  FRA   F        175   27
# 237  FRA   M        163   22
# 238  FRA   F        192   31
# 239  FRA   F        178   19
# 240  FRA   F        178   21
# 241  FRA   M        165   23
# 242  FRA   M        168   27
# 243  FRA   M        180   31
# 244  FRA   M        196   29
# 245  FRA   G        185   33
# 246  FRA   D        190   32
# 247  FRA   F        173   24
# 248  FRA   D        182   25
# 249  FRA   M        179   25
# 250  FRA   D        184   22
# 251  FRA   D        180   23
# 252  FRA   G        190   25

# %%
sns.boxplot(x='Pos', y='Height_cm', data=df, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Height_cm', data=df, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Height_cm', data=df2018winners, color="black")

# %%
sns.boxplot(x='Pos', y='Age', data=df, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Age', data=df, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Age', data=df2018winners, color="black")

# %%
sns.boxplot(x='Pos', y='Height_cm', data=df, palette="Paired")
sns.stripplot(x='Pos', y='Height_cm', data=df, color="grey", alpha=.5, jitter = True)

# %%
df2014 = pd.read_csv('WorldCupStats2014.csv', encoding='latin-1')

# %%
df2014.head()
# Out:
#    Number          Name  Nat Pos  Height  Height_cm  Weight Date of Birth  \
# 0       1     Jefferson  BRA   G    1.87        187      82    02/01/1983
# 1       2  Daniel Alves  BRA   D    1.73        173      64    06/05/1983
# 2       3  Thiago Silva  BRA   D    1.83        183      79    22/09/1984
# 3       4    David Luiz  BRA   D    1.89        189      84    22/04/1987
# 4       5   Fernandinho  BRA   M    1.76        176      67    04/05/1985
#
#    Age     Birth Place      Current Club Group  Unnamed: 12
# 0   31     SÜo Vicente          Botafogo     A          NaN
# 1   31        Juazeiro         Barcelona     A          NaN
# 2   29  Rio de Janeiro  Paris St-Germain     A          NaN
# 3   27       SÜo Paulo           Chelsea     A          NaN
# 4   29        Londrina      Manchester C     A          NaN

# %%
df2014winners = df2014[['Nat','Pos','Height_cm', 'Age']]

# %%
df2014winners = df2014winners[df2014winners['Nat'] == 'GER']

# %%
df2014winners
# Out:
#      Nat Pos  Height_cm
# 552  GER   G        192
# 553  GER   D        186
# 554  GER   M        187
# 555  GER   D        187
# 556  GER   D        192
# 557  GER   M        189
# 558  GER   M        183
# 559  GER   M        182
# 560  GER   F        175
# 561  GER   F        182
# 562  GER   F        184
# 563  GER   G        185
# 564  GER   M        186
# 565  GER   M        183
# 566  GER   D        183
# 567  GER   D        170
# 568  GER   D        198
# 569  GER   M        182
# 570  GER   M        176
# 571  GER   D        192
# 572  GER   D        184
# 573  GER   G        188
# 574  GER   M        190

# %%
sns.boxplot(x='Pos', y='Height_cm', data=df2014, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Height_cm', data=df2014, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Height_cm', data=df2014winners, color="black")

# %%
sns.boxplot(x='Pos', y='Age', data=df2014, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Age', data=df2014, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Age', data=df2014winners, color="black")

# %%
df2010 = pd.read_csv('WorldCupStats2010.csv', encoding='latin-1')

# %%
df2010.head()
# Out:
#    Number                Name  Nat Pos  Height  Height_cm  Weight  \
# 0       1         Hugo Lloris  FRA   G    1.88        188      78
# 1       2        Bacary Sagna  FRA   D    1.76        176      72
# 2       3         Eric Abidal  FRA   D    1.86        186      75
# 3       4  Anthony R_veillre  FRA   D    1.81        181      76
# 4       5      William Gallas  FRA   D    1.83        183      72
#
#   Date of Birth  Age       Birth Place Current Club Group
# 0    26/12/1986   23              Nice         Lyon     A
# 1    14/02/1983   27              Sens      Arsenal     A
# 2    11/07/1979   30              Lyon    Barcelona     A
# 3    10/11/1979   30  Dou_-La-Fontaine         Lyon     A
# 4    17/08/1977   32          Asnieres      Arsenal     A

# %%
df2010winners = df2010[['Nat','Pos','Height_cm','Age']]

# %%
df2010winners = df2010winners[df2010winners['Nat'] == 'ESP']

# %%
df2010winners
# Out:
#      Nat Pos  Height_cm Age
# 690  ESP   G        185  29
# 691  ESP   D        187  24
# 692  ESP   D        192  23
# 693  ESP   D        183  30
# 694  ESP   D        178  32
# 695  ESP   M        170  26
# 696  ESP   F        175  28
# 697  ESP   M        170  30
# 698  ESP   F        186  26
# 699  ESP   M        177  23
# 700  ESP   D        182  32
# 701  ESP   G        183  28
# 702  ESP   F        170  22
# 703  ESP   M        183  28
# 704  ESP   D        183  24
# 705  ESP   M        189  21
# 706  ESP   D        183  27
# 707  ESP   F        169  22
# 708  ESP   F        195  25
# 709  ESP   M        190  21
# 710  ESP   M        170  24
# 711  ESP   M        170  24
# 712  ESP   G        188  27

# %%
sns.axes_style()
# Out:
# {'axes.axisbelow': True,
#  'axes.edgecolor': '.8',
#  'axes.facecolor': 'white',
#  'axes.grid': True,
#  'axes.labelcolor': '.15',
#  'axes.linewidth': 1.0,
#  'figure.facecolor': 'white',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'grid.color': '.8',
#  'grid.linestyle': '-',
#  'image.cmap': 'rocket',
#  'legend.frameon': False,
#  'legend.numpoints': 1,
#  'legend.scatterpoints': 1,
#  'lines.solid_capstyle': 'round',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'xtick.direction': 'out',
#  'xtick.major.size': 0.0,
#  'xtick.minor.size': 0.0,
#  'ytick.color': '.15',
#  'ytick.direction': 'out',
#  'ytick.major.size': 0.0,
#  'ytick.minor.size': 0.0}

# %%
sns.set_style("darkgrid")

# %%
sns.boxplot(x='Pos', y='Height_cm', data=df2010, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Height_cm', data=df2010, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Height_cm', data=df2010winners, color="black")

# %%
sns.boxplot(x='Pos', y='Age', data=df2010, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Age', data=df2010, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Age', data=df2010winners, color="black")

# %%
df2006 = pd.read_csv('WorldCupStats2006.csv', encoding='latin-1')

# %%
df2006.head()
# Out:
#    Number                Name         Nat Pos Height  Height_cm Weight  \
# 0       1        Alvaro Mesn  Costa Rics   G   5'11     180.34  12 08
# 1       2     Jervis Drummond  Costa Rics   D   5'08     172.72  11 07
# 2       3  Luis Antonio Marn  Costa Rics   D   5'10     177.80  12 04
# 3       4       Michael Umaa  Costa Rics   D   6'00     182.88  11 07
# 4       5   Gilberto Martinez  Costa Rics   D   5'09     175.26  11 05
#
#   Date of Birth  Age Birth Place        Current Club Group
# 0    24/12/1972   33    Alajuela        CS Herediano     A
# 1    08/09/1976   29       Limn  Deportivo Saprissa     A
# 2    10/08/1974   31    San Jos      LD Alajuelense     A
# 3    16/07/1982   23    San Jos              Brujas     A
# 4    01/10/1979   26     Golfito             Brescia     A

# %%
df2006winners = df2006[["Nat", "Pos", "Age", "Height_cm"]]

# %%
df2006winners = df2006winners[df2006winners["Nat"]== "Italy"]

# %%
df2006winners
# Out:
#        Nat Pos  Age  Height_cm
# 414  Italy   G   28     190.50
# 415  Italy   D   24     182.88
# 416  Italy   M   28     190.50
# 417  Italy   M   22     182.88
# 418  Italy   D   32     175.26
# 419  Italy   D   25     185.42
# 420  Italy   F   31     172.72
# 421  Italy   M   28     177.80
# 422  Italy   F   29     193.04
# 423  Italy   F   29     180.34
# 424  Italy   F   23     182.88
# 425  Italy   G   36     180.34
# 426  Italy   D   30     187.96
# 427  Italy   G   24     187.96
# 428  Italy   F   29     187.96
# 429  Italy   M   29     177.80
# 430  Italy   M   28     180.34
# 431  Italy   F   32     180.34
# 432  Italy   D   29     180.34
# 433  Italy   M   28     177.80
# 434  Italy   M   27     177.80
# 435  Italy   D   29     182.88
# 436  Italy   D   32     193.04

# %%
sns.boxplot(x='Pos', y='Height_cm', data=df2006, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Height_cm', data=df2006, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Height_cm', data=df2006winners, color="black")

# %%
sns.boxplot(x='Pos', y='Age', data=df2006, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Age', data=df2006, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Age', data=df2006winners, color="black")

# %%
df2002 = pd.read_csv('WorldCupStats2002.csv', encoding='latin-1')
df2002winners = df2002[["Nat", "Pos", "Age", "Height_cm"]]
df2002winners = df2002winners[df2002winners["Nat"]== "Brazil"]
sns.boxplot(x='Pos', y='Height_cm', data=df2002, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Height_cm', data=df2002, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Height_cm', data=df2002winners, color="black")

# %%
sns.boxplot(x='Pos', y='Age', data=df2002, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Age', data=df2002, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Age', data=df2002winners, color="black")

# %%
df1998 = pd.read_csv('WorldCupStats1998.csv', encoding='latin-1')
df1998winners = df1998[["Nat", "Pos", "Age", "Height_cm"]]
df1998winners = df1998winners[df1998winners["Nat"]== "France"]
sns.boxplot(x='Pos', y='Height_cm', data=df1998, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Height_cm', data=df1998, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Height_cm', data=df1998winners, color="black")

# %%
sns.boxplot(x='Pos', y='Age', data=df1998, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Age', data=df1998, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Age', data=df1998winners, color="black")

# %%
df1994 = pd.read_csv('WorldCupStats1994.csv', encoding='latin-1')
df1994winners = df1994[["Nat", "Pos", "Age", "Height_cm"]]
df1994winners = df1994winners[df1994winners["Nat"]== "Brazil"]
sns.boxplot(x='Pos', y='Height_cm', data=df1994, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Height_cm', data=df1994, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Height_cm', data=df1994winners, color="black")

# %%
sns.boxplot(x='Pos', y='Age', data=df1994, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Age', data=df1994, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Age', data=df1994winners, color="black")

# %%
df1990 = pd.read_csv('WorldCupStats1990.csv', encoding='latin-1')
df1990winners = df1990[["Nat", "Pos", "Age", "Height_cm"]]
df1990winners = df1990winners[df1990winners["Nat"]== "West Germany"]
sns.boxplot(x='Pos', y='Height_cm', data=df1990, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Height_cm', data=df1990, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Height_cm', data=df1990winners, color="black")

# %%
sns.boxplot(x='Pos', y='Age', data=df1990, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Age', data=df1990, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Age', data=df1990winners, color="black")

# %%
df1986 = pd.read_csv('WorldCupStats1986.csv', encoding='latin-1')
df1986winners = df1986[["Nat", "Pos", "Age", "Height_cm"]]
df1986winners = df1986winners[df1986winners["Nat"]== "Argentina"]
sns.boxplot(x='Pos', y='Height_cm', data=df1986, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Height_cm', data=df1986, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Height_cm', data=df1986winners, color="black")

# %%
sns.boxplot(x='Pos', y='Age', data=df1986, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Age', data=df1986, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Age', data=df1986winners, color="black")

# %%
df1982 = pd.read_csv('WorldCupStats1982.csv', encoding='latin-1')
df1982winners = df1982[["Nat", "Pos", "Age", "Height_cm"]]
df1982winners = df1982winners[df1982winners["Nat"]== "Italy"]
sns.boxplot(x='Pos', y='Height_cm', data=df1982, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Height_cm', data=df1982, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Height_cm', data=df1982winners, color="black")

# %%
sns.boxplot(x='Pos', y='Age', data=df1982, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Age', data=df1982, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Age', data=df1982winners, color="black")

# %%
df1978 = pd.read_csv('WorldCupStats1978.csv', encoding='latin-1')
df1978winners = df1978[["Nat", "Pos", "Age", "Height_cm"]]
df1978winners = df1978winners[df1978winners["Nat"]== "Argentina"]
sns.boxplot(x='Pos', y='Height_cm', data=df1978, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Height_cm', data=df1978, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Height_cm', data=df1978winners, color="black")

# %%
sns.boxplot(x='Pos', y='Age', data=df1978, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Age', data=df1978, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Age', data=df1978winners, color="black")

# %%
df1974 = pd.read_csv('WorldCupStats1974.csv', encoding='latin-1')
df1974winners = df1974[["Nat", "Pos", "Age", "Height_cm"]]
df1974winners = df1974winners[df1974winners["Nat"]== "West Germany"]
sns.boxplot(x='Pos', y='Height_cm', data=df1974, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Height_cm', data=df1974, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Height_cm', data=df1974winners, color="black")

# %%
sns.boxplot(x='Pos', y='Age', data=df1974, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Age', data=df1974, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Age', data=df1974winners, color="black")

# %%
df1970 = pd.read_csv('WorldCupStats1970.csv', encoding='latin-1')
df1970winners = df1970[["Nat", "Pos", "Age", "Height_cm"]]
df1970winners = df1970winners[df1970winners["Nat"]== "Brazil"]
sns.boxplot(x='Pos', y='Height_cm', data=df1970, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Height_cm', data=df1970, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Height_cm', data=df1970winners, color="black")

# %%
sns.boxplot(x='Pos', y='Age', data=df1970, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Age', data=df1970, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Age', data=df1970winners, color="black")

# %%
df1966 = pd.read_csv('WorldCupStats1966.csv', encoding='latin-1')
df1966winners = df1966[["Nat", "Pos", "Age", "Height_cm"]]
df1966winners = df1966winners[df1966winners["Nat"]== "England"]
sns.boxplot(x='Pos', y='Height_cm', data=df1966, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Height_cm', data=df1966, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Height_cm', data=df1966winners, color="black")

# %%
sns.boxplot(x='Pos', y='Age', data=df1966, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Age', data=df1966, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Age', data=df1966winners, color="black")

# %%
os.getcwd()
# Out:
# '/Users/tomjones/Desktop'

# %%
df1970 = pd.read_csv('WorldCupStats1970.csv', encoding='latin-1')
df1970winners = df1970[["Nat", "Pos", "Age", "Height_cm"]]
df1970winners = df1970winners[df1970winners["Nat"]== "Brazil"]

sns.boxplot(x='Pos', y='Height_cm', data=df1970, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Height_cm', data=df1970, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Height_cm', data=df1970winners, color="black")
# Out:
#   File "<ipython-input-226-aba6e42562ff>", line 1
#     plot1970 = (df1970 = pd.read_csv('WorldCupStats1970.csv', encoding='latin-1')
#                        ^
# SyntaxError: invalid syntax

# %%
df3 = sns.boxplot(x='Pos', y='Height_cm', data=df1970, palette="Paired", boxprops=dict(alpha=.7))
df3 = sns.swarmplot(x='Pos', y='Height_cm', data=df1970, color="grey", alpha=.5)
df3 = sns.swarmplot(x='Pos', y='Height_cm', data=df1970winners, color="black")

# %%
sns.boxplot(x='Pos', y='Height_cm', data=df1970, palette="Paired", boxprops=dict(alpha=.7))

# %%
g = sns.FacetGrid(df1970winners, col="Height_cm")

# %%
a4_dims = (11.7, 8.27)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


# plot
sns.set_style('darkgrid')
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(8, 5)

sns.boxplot(x='Pos', y='Height_cm', data=df1970, palette="Paired", boxprops=dict(alpha=.7), ax=ax)
sns.swarmplot(x='Pos', y='Height_cm', data=df1970, color="grey", alpha=.8, ax=ax)
sns.swarmplot(x='Pos', y='Height_cm', data=df1970winners, color="Black", ax=ax)

   
sns.despine()

fig.savefig('example.png')

# %%
# plot
sns.set_style('whitegrid')
fig, ax = plt.subplots( ncols=2)
# the size of A4 paper
fig.set_size_inches(15, 6)

ds = sns.boxplot(x='Pos', y='Height_cm', data=df1950, palette="Paired", boxprops=dict(alpha=.7), ax=ax[0])
ds = sns.swarmplot(x='Pos', y='Height_cm', data=df1950, color="grey", alpha=.6, ax=ax[0])
ds = sns.swarmplot(x='Pos', y='Height_cm', data=df1950winners, color="Black", ax=ax[0])

ds.set(xlabel='Position', ylabel='Age', title="Height")

ds = sns.boxplot(x='Pos', y='Age', data=df1950, palette="Paired", boxprops=dict(alpha=.7), ax=ax[1])
ds = sns.swarmplot(x='Pos', y='Age', data=df1950, color="grey", alpha=.5, ax=ax[1])
ds = sns.swarmplot(x='Pos', y='Age', data=df1950winners, color="black", ax=ax[1])

ds.set(xlabel='Position', ylabel='Age', title="Age")


   
sns.despine()
plt.show(fig)
fig.savefig('1950.png')

# %%
df1950 = pd.read_csv('WorldCupStats1950.csv', encoding='latin-1')
df1950winners = df1950[["Nat", "Pos", "Age", "Height_cm"]]
df1950winners = df1950winners[df1950winners["Nat"]== "England"]
sns.boxplot(x='Pos', y='Height_cm', data=df1950, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Height_cm', data=df1950, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Height_cm', data=df1950winners, color="black")

# %%
sns.boxplot(x='Pos', y='Age', data=df1962, palette="Paired", boxprops=dict(alpha=.7))
sns.swarmplot(x='Pos', y='Age', data=df1962, color="grey", alpha=.5)
sns.swarmplot(x='Pos', y='Age', data=df1962winners, color="black")

# %%
os.getcwd()
